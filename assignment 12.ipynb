# %%
import pandas as pd
videogamesales = pd.read_csv("./input/vgsales.csv")

# %%
videogamesales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # Groupby

# %%
videogamesales.groupby(by="Genre").mean()
# Out:
#                       Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Action         7973.879071  2007.909929  0.264726  0.158323  0.048236
# Adventure     11532.787714  2008.130878  0.082271  0.049868  0.040490
# Fighting       7646.511792  2004.630383  0.263667  0.119481  0.103007
# Misc           8561.847039  2007.258480  0.235906  0.124198  0.061967
# Platform       6927.251693  2003.820776  0.504571  0.227573  0.147596
# Puzzle         9627.381443  2005.243433  0.212680  0.087251  0.098471
# Racing         7961.515612  2004.840131  0.287766  0.190865  0.045388
# Role-Playing   8086.174731  2007.055744  0.219946  0.126384  0.236767
# Shooter        7369.367939  2005.918877  0.444733  0.239137  0.029221
# Simulation     8626.085352  2006.567568  0.211430  0.130773  0.073472
# Sports         7425.026428  2005.477865  0.291283  0.160635  0.057702
# Strategy      10071.897210  2005.599106  0.100881  0.066579  0.072628
#
#               Other_Sales  Global_Sales
# Genre
# ...

# %%
videogamesales.groupby(by="Publisher").mean()
# Out:
#                                       Rank         Year  NA_Sales  EU_Sales  \
# Publisher
# 10TACLE Studios               14064.000000  2006.666667  0.023333  0.013333
# 1C Company                    14412.333333  2010.333333  0.003333  0.023333
# 20th Century Fox Video Games   5453.200000  1981.400000  0.364000  0.020000
# 2D Boy                        14013.000000  2008.000000  0.000000  0.030000
# 3DO                            8037.333333  2000.500000  0.180000  0.084444
# ...                                    ...          ...       ...       ...
# id Software                   14602.000000  1992.000000  0.020000  0.000000
# imageepoch Inc.               15344.000000  2014.000000  0.000000  0.000000
# inXile Entertainment          10758.000000  2015.000000  0.020000  0.060000
# mixi, Inc                      2411.000000  2015.000000  0.000000  0.000000
# responDESIGN                  12316.500000  2004.500000  0.045000  0.020000
#
# ...

# %%
videogamesales.groupby(by="Platform").mean()
# Out:
#                   Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# 2600       4403.496241  1982.137931  0.681203  0.041128  0.000000
# 3DO       14372.666667  1994.666667  0.000000  0.000000  0.033333
# 3DS        9160.400786  2013.062000  0.154951  0.114971  0.191257
# DC         8771.423077  1999.942308  0.104423  0.032500  0.164615
# DS         9637.462321  2008.201125  0.180633  0.089991  0.081170
# GB         3392.030612  1995.958763  1.166531  0.487959  0.868571
# GBA        8682.176399  2003.210851  0.228151  0.091545  0.057579
# GC         8664.390288  2003.400369  0.240036  0.069622  0.038813
# GEN        7037.740741  1993.037037  0.713704  0.204444  0.098889
# GG        13527.000000  1992.000000  0.000000  0.000000  0.040000
# N64        6530.373041  1998.531646  0.435799  0.128715  0.107273
# NES        1906.438776  1987.153061  1.285102  0.215816  1.006633
# NG        10665.666667  1994.500000  0.000000  0.000000  0.120000
# ...

# %%
import seaborn as sns

# %% [markdown]
# # Genre

# %%
sns.barplot(y="Global_Sales", x="Genre", data=videogamesales)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Global_Sales'>

# %%
sns.barplot(y="EU_Sales", x="Genre", data=videogamesales)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='EU_Sales'>

# %% [markdown]
# # Platform

# %%
sns.barplot(y="Global_Sales", x="Platform", data=videogamesales)
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='Global_Sales'>

# %%
sns.barplot(y="EU_Sales", x="Platform", data=videogamesales)
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='EU_Sales'>

# %% [markdown]
# # Publisher

# %% [markdown]
# Barplot te onoverzichtelijk
