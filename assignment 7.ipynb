# %%
import pandas as pd

# %%
videogamesales = pd.read_csv("./input/vgsales.csv")

# %%
videogamesales['Global_Sales'].plot(kind='hist', bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
videogamesales['JP_Sales'].plot(kind='hist', bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### The distribution looks like a Exponential Distribution
