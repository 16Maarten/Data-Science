# %%
import pandas as pd
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
penguinsCorrelations = penguins.corr()
penguinsCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\acer\AppData\Local\Temp/ipykernel_6080/1330701415.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   penguinsCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_d98c8_row0_col0, #T_d98c8_row1_col1, #T_d98c8_row2_col2, #T_d98c8_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d98c8_row0_col1, #T_d98c8_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_d98c8_row0_col2, #T_d98c8_row2_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_d98c8_row0_col3, #T_d98c8_row3_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_d98c8_row1_col2, #T_d98c8_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d98c8_row1_col3, #T_d98c8_row3_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d98c8_row2_col3, #T_d98c8_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# De correlaties voldoen niet aan mijn verwachting ik had namelijk een sterk verband verwacht tussen bill_length_mm en bill_depth_mm

# %% [markdown]
# # The strongest positive correlation

# %%
penguins.plot(kind='scatter', x='flipper_length_mm', y='body_mass_g')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# # The strongest negative correlation

# %%
penguins.plot(kind='scatter', x='body_mass_g', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='bill_depth_mm'>

# %% [markdown]
# # The weakest correlation

# %%
penguins.plot(kind='scatter', x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>
